# %%
import os 
os.environ["GOOGLE_API_KEY"] = "AIzaSyDWYT_j284qH4_0Du6HuOqmMQ1F16Z9drI"

# %%
import google.generativeai as genai
import os
import time
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))  

model = genai.GenerativeModel("gemini-pro")

def get_disease_severity(disease_name: str):
    system_prompt = ("You are a Doctor answering medical questions in one line. "
                     "You must provide a severity score of a disease on a scale of 1-10. "
                     "Unsevere to mid-range diseases should be between (1-3), "
                     "lower mid to upper mid (4-7), upper mid to most severe (7-9), "
                     "and ultra severe (9-10) as a single number.")
    
    user_question = f"Tell the severity of {disease_name}"
    prompt = f"{system_prompt}\n\n{user_question}"
    response = model.generate_content(prompt)
    
    try:
        severity = int(response.text.strip())  
    except ValueError:
        severity = "Unknown"
    
    return [disease_name, severity]


disease_list = [['Open wound due to trauma', 'Intracerebral hemorrhage', 'Alzheimer disease', 'Vaginismus', 'Systemic lupus erythematosis (SLE)', 'Premature ovarian failure', 'Thoracic outlet syndrome', 'Ganglion cyst', 'Dislocation of the knee', 'Crohn disease'], ['Postoperative infection', 'Folate deficiency', 'Fluid overload', 'Atrial flutter', 'Skin disorder', 'Floaters', 'Tooth disorder', 'Heart attack', 'Open wound of the abdomen', 'Fracture of the leg'], ['Oral thrush (yeast infection)', 'Pityriasis rosea', 'Allergy to animals', 'Orthostatic hypotension', 'Obstructive sleep apnea (OSA)', 'Hypokalemia', 'Psoriasis', 'Dislocation of the shoulder', 'Intussusception', 'Cervicitis'], ['Abscess of the pharynx', 'Primary thrombocythemia', 'Arthritis of the hip', 'Decubitus ulcer', 'Hypernatremia', 'Sensorineural hearing loss', 'Chronic ulcer', 'Osteoporosis', 'Ileus', 'Sickle cell crisis'], ['Urethritis', 'Prostatitis', "Otitis externa (swimmer's ear)", 'Poisoning due to anticonvulsants', 'Testicular torsion', 'Tricuspid valve disease', 'Urethral stricture', 'Vitamin D deficiency', 'Hydatidiform mole', 'Pain disorder affecting the neck'], ['Tuberculosis', 'Pelvic fistula', 'Acute bronchiolitis', 'Presbyopia', 'Dementia', 'Insect bite', 'Paroxysmal ventricular tachycardia', 'Congenital heart defect', 'Connective tissue disorder', 'Foreign body in the eye'], ['Poisoning due to gas', 'Pyogenic skin infection', 'Endometrial hyperplasia', 'Acanthosis nigricans', 'Central atherosclerosis', 'Viral exanthem', 'Blastomycosis', 'Noninfectious gastroenteritis', 'Benign prostatic hyperplasia (BPH)', 'Menopause'], ['Primary immunodeficiency', 'Ovarian cancer', 'Cataract', 'Dislocation of the hip', 'Spinal stenosis', 'Intestinal obstruction', 'Heart contusion', 'Congenital malformation syndrome', 'Sporotrichosis', 'Lymphangitis'], ['Wernicke Korsakoff syndrome', 'Intestinal disease', 'Acute bronchitis', 'Persistent vomiting of unknown cause', 'Open wound of the foot', 'Myocarditis', 'Preeclampsia', 'Ischemic heart disease', 'Neurofibromatosis', 'Chickenpox'], ['Pancreatic cancer', 'Neuropathy due to drugs', 'Croup', 'Idiopathic excessive menstruation', 'Amblyopia', 'Meckel diverticulum', 'Dislocation of the wrist', 'Ear drum damage', 'Erectile dysfunction', 'Temporary or benign blood in urine'], ['Kidney disease due to longstanding hypertension', 'Chondromalacia of the patella', 'Onychomycosis', 'Urethral disorder', 'Lyme disease', 'Iron deficiency anemia', 'Acute respiratory distress syndrome (ARDS)', 'Toxic multinodular goiter', 'Open wound of the finger', 'Autonomic nervous system disorder'], ['Psychosexual disorder', 'Anemia', 'Tendinitis', 'Common cold', 'Amyotrophic lateral sclerosis (ALS)', 'Central retinal artery or vein occlusion', 'Paroxysmal supraventricular tachycardia', 'Venous insufficiency', 'Trichomonas infection', 'Acne'], ['Depression', 'Drug abuse', 'Urinary tract obstruction', 'Diabetes insipidus', 'Iridocyclitis', 'Varicocele of the testicles', 'Irritable bowel syndrome', 'Fracture of the foot', 'Ovarian cyst', 'Chlamydia'], ['Parasitic disease', 'Fracture of the jaw', 'Cytomegalovirus infection', 'Lipoma', 'Female genitalia infection', 'Pulmonary hypertension', 'Thyroid nodule', 'Broken tooth', 'Dumping syndrome', 'Lymphadenitis'], ['Injury to the face', 'Aortic valve disease', 'Rheumatoid arthritis', 'Spermatocele', 'Impetigo', 'Anal fistula', 'Hypothermia', 'Oppositional disorder', 'Migraine', 'Diabetic peripheral neuropathy'], ['Testicular disorder', 'Gestational diabetes', 'Hidradenitis suppurativa', 'Valley fever', 'Conjunctivitis due to bacteria', 'Lewy body dementia', 'Marfan syndrome', 'Multiple myeloma', 'Head injury', 'Ascending cholangitis'], ['Idiopathic irregular menstrual cycle', 'Interstitial lung disease', 'Mononeuritis', 'Malaria', 'Somatization disorder', 'Hypovolemia', 'Schizophrenia', 'Knee ligament or meniscus tear', 'Endocarditis', 'Sepsis'], ['Heat stroke', 'Cholecystitis', 'Cardiac arrest', 'Cardiomyopathy', 'Social phobia', 'Meningitis', 'Spherocytosis', 'Hormone disorder', 'Raynaud disease', 'Reactive arthritis'], ['Scabies', 'Ear wax impaction', 'Hypertension of pregnancy', 'Peripheral arterial embolism', 'Rosacea', 'Fracture of the skull', 'Uveitis', 'Fracture of the facial bones', 'Tracheitis', 'Jaw disorder'], ['Perirectal infection', 'Breast cyst', 'Post-traumatic stress disorder (PTSD)', 'Kidney cancer', 'Vulvar cancer', 'Blepharitis', 'Celiac disease', 'Cystitis', 'Sickle cell anemia', 'Subconjunctival hemorrhage'], ['Hemorrhoids', 'Contact dermatitis', 'Sinus bradycardia', 'High blood pressure', 'Pelvic inflammatory disease', 'Liver disease', 'Chronic constipation', 'Thyroid cancer', 'Flu', 'Friedrich ataxia'], ['Tic (movement) disorder', 'Skin polyp', 'Brachial neuritis', 'Cervical cancer', 'Adrenal adenoma', 'Esophagitis', 'Gas gangrene', 'Yeast infection', 'Spina bifida', 'Drug poisoning due to medication'], ['Alcoholic liver disease', 'Malignant hypertension', 'Diverticulitis', 'Moyamoya disease', 'Heat exhaustion', 'Psychotic disorder', 'Frostbite', 'Atrophy of the corpus cavernosum', 'Smoking or tobacco addiction', 'Sprain or strain'], ['Essential tremor', 'Open wound of the ear', 'Foreign body in the nose', 'Idiopathic painful menstruation', 'Down syndrome', 'Idiopathic infrequent menstruation', 'Pneumothorax', 'De Quervain disease', 'Fracture of the vertebra', 'Human immunodeficiency virus infection (HIV)'], ['Mumps', 'Subarachnoid hemorrhage', 'Acute fatty liver of pregnancy (AFLP)', 'Ectropion', 'Scar', 'Lactose intolerance', 'Eustachian tube dysfunction (ear disorder)', 'Appendicitis', 'Graves disease', 'Dissociative disorder'], ['Open wound of the face', 'Dislocation of the vertebra', 'Phimosis', 'Hyperemesis gravidarum', 'Pregnancy', 'Thalassemia', 'Placenta previa', 'Epidural hemorrhage', 'Septic arthritis', "Athlete's foot"], ['Pleural effusion', 'Aphakia', 'Vulvar disorder', 'Vitamin B deficiency', 'Sialoadenitis', 'Gynecomastia', 'Urinary tract infection', 'Histoplasmosis', 'Erythema multiforme', 'Scoliosis'], ['Bunion', 'Arrhythmia', 'Paget disease', 'Trigeminal neuralgia', 'Ankylosing spondylitis', 'Peripheral nerve disorder', 'Sebaceous cyst', 'Poisoning due to antipsychotics', 'Behcet disease', 'Neurosis'], ['Prostate cancer', 'Cerebral edema', 'Dislocation of the finger', 'Birth trauma', 'Chronic pancreatitis', 'Hematoma', 'Carcinoid syndrome', 'Open wound of the head', 'Seborrheic keratosis', 'Burn'], ['Spontaneous abortion', 'Genital herpes', 'Adjustment reaction', 'Gallstone', 'Multiple sclerosis', 'Zenker diverticulum', 'Fracture of the pelvis', 'Pneumoconiosis', 'Hyperlipidemia', 'Ulcerative colitis'], ['Male genitalia infection', 'HPV', 'Angina', 'Injury to the spinal cord', 'Nasal polyp', 'Lichen simplex', 'Trichiasis', 'Acariasis', 'Colorectal cancer', 'Skin pigmentation disorder'], ['Factitious disorder', 'Lymphogranuloma venereum', 'Galactorrhea of unknown cause', 'G6PD enzyme deficiency', 'Nerve impingement near the shoulder', 'Toxoplasmosis', 'Fibroadenoma', 'Open wound of the hand', 'Missed abortion', 'Diabetic ketoacidosis'], ['Granuloma inguinale', 'Hemorrhagic fever', 'Obsessive compulsive disorder (OCD)', 'Injury of the ankle', 'Hyponatremia', 'Stricture of the esophagus', 'Fracture of the ankle', 'Soft tissue sarcoma', 'Bone disorder', 'Epilepsy'], ['Personality disorder', 'Shingles (herpes zoster)', 'Tourette syndrome', 'Avascular necrosis', 'Strep throat', 'Spinocerebellar ataxia', 'Osteomyelitis', 'Sjogren syndrome', 'Adhesive capsulitis of the shoulder', 'Viral hepatitis'], ['Tonsillar hypertrophy', 'Gastritis', 'Skin cancer', 'Rheumatic fever', 'Aphthous ulcer', 'Tonsillitis', 'Intestinal cancer', 'Rocky Mountain spotted fever', 'Stomach cancer', 'Developmental disability'], ['Acute stress reaction', 'Delirium', 'Callus', 'Guillain Barre syndrome', 'Lumbago', 'Deviated nasal septum', 'Hemangioma', 'Patau syndrome', 'Peripheral arterial disease', 'Chronic back pain'], ['Heart failure', 'Conjunctivitis', 'Herniated disk', 'Rhabdomyolysis', 'Breast infection (mastitis)', 'Abdominal aortic aneurysm', 'Pulmonary embolism', 'Conduct disorder', 'Air embolism', 'Mastectomy'], ['Epididymitis', 'Premature rupture of amniotic membrane', 'Molluscum contagiosum', 'Necrotizing fasciitis', 'Benign vaginal discharge (leukorrhea)', 'Bladder obstruction', 'Melanoma', 'Cervical disorder', 'Laryngitis', 'Dyshidrosis'], ['Poisoning due to opioids', 'Diaper rash', 'Lichen planus', 'Gastroduodenal ulcer', 'Inguinal hernia', 'Eczema', 'Asperger syndrome', 'Mucositis', 'Paronychia', 'Open wound of the jaw'], ['White blood cell disease', 'Kaposi sarcoma', 'Spondylolisthesis', 'Pseudotumor cerebri', 'Conjunctivitis due to virus', 'Open wound of the nose', 'Seasonal Viral Flu']]
with open("severitydata.txt", "w") as file:
        for i in range(len(disease_list)):
            severity_list = [get_disease_severity(disease) for disease in disease_list[i]]
            file.write(f"{severity_list}\n")
            print(f"{severity_list}\n")
            time.sleep(60)
# Out:
# [['Open wound due to trauma', 6], ['Intracerebral hemorrhage', 8], ['Alzheimer disease', 7], ['Vaginismus', 'Unknown'], ['Systemic lupus erythematosis (SLE)', 7], ['Premature ovarian failure', 7], ['Thoracic outlet syndrome', 2], ['Ganglion cyst', 2], ['Dislocation of the knee', 7], ['Crohn disease', 6]]
#
# [['Postoperative infection', 5], ['Folate deficiency', 3], ['Fluid overload', 7], ['Atrial flutter', 5], ['Skin disorder', 3], ['Floaters', 2], ['Tooth disorder', 5], ['Heart attack', 9], ['Open wound of the abdomen', 9], ['Fracture of the leg', 6]]
#
# [['Oral thrush (yeast infection)', 5], ['Pityriasis rosea', 'Unknown'], ['Allergy to animals', 2], ['Orthostatic hypotension', 3], ['Obstructive sleep apnea (OSA)', 7], ['Hypokalemia', 4], ['Psoriasis', 4], ['Dislocation of the shoulder', 6], ['Intussusception', 7], ['Cervicitis', 3]]
#
# [['Abscess of the pharynx', 6], ['Primary thrombocythemia', 'Unknown'], ['Arthritis of the hip', 5], ['Decubitus ulcer', 5], ['Hypernatremia', 7], ['Sensorineural hearing loss', 5], ['Chronic ulcer', 6], ['Osteoporosis', 7], ['Ileus', 'Unknown'], ['Sickle cell crisis', 7]]
#
# [['Urethritis', 'Unknown'], ['Prostatitis', 'Unknown'], ["Otitis externa (swimmer's ear)", 4], ['Poisoning due to anticonvulsants', 'Unknown'], ['Testicular torsion', 9], ['Tricuspid valve disease', 7], ['Urethral stricture', 5], ['Vitamin D deficiency', 4], ['Hydatidiform mole', 5], ['Pain disorder affecting the neck', 4]]
#
# [['Tuberculosis', 7], ['Pelvic fistula', 'Unknown'], ['Acute bronchiolitis', 4], ['Presbyopia', 3], ['Dementia', 7], ['Insect bite', 1], ['Paroxysmal ventricular tachycardia', 8], ['Congenital heart defect', 8], ['Connective tissue disorder', 7], ['Foreign body in the eye', 4]]
#
# [['Poisoning due to gas', 7], ['Pyogenic skin infection', 5], ['Endometrial hyperplasia', 4], ['Acanthosis nigricans', 3], ['Central atherosclerosis', 4], ['Viral exanthem', 2], ['Blastomycosis', 6], ['Noninfectious gastroenteritis', 4], ['Benign prostatic hyperplasia (BPH)', 'Unknown'], ['Menopause', 4]]
#
# [['Primary immunodeficiency', 'Unknown'], ['Ovarian cancer', 7], ['Cataract', 6], ['Dislocation of the hip', 5], ['Spinal stenosis', 5], ['Intestinal obstruction', 7], ['Heart contusion', 3], ['Congenital malformation syndrome', 7], ['Sporotrichosis', 4], ['Lymphangitis', 5]]
#
# [['Wernicke Korsakoff syndrome', 7], ['Intestinal disease', 7], ['Acute bronchitis', 4], ['Persistent vomiting of unknown cause', 7], ['Open wound of the foot', 7], ['Myocarditis', 7], ['Preeclampsia', 7], ['Ischemic heart disease', 7], ['Neurofibromatosis', 3], ['Chickenpox', 2]]
#
# [['Pancreatic cancer', 8], ['Neuropathy due to drugs', 4], ['Croup', 5], ['Idiopathic excessive menstruation', 'Unknown'], ['Amblyopia', 3], ['Meckel diverticulum', 4], ['Dislocation of the wrist', 6], ['Ear drum damage', 6], ['Erectile dysfunction', 'Unknown'], ['Temporary or benign blood in urine', 3]]
#
# [['Kidney disease due to longstanding hypertension', 6], ['Chondromalacia of the patella', 4], ['Onychomycosis', 2], ['Urethral disorder', 4], ['Lyme disease', 7], ['Iron deficiency anemia', 5], ['Acute respiratory distress syndrome (ARDS)', 9], ['Toxic multinodular goiter', 7], ['Open wound of the finger', 'Unknown'], ['Autonomic nervous system disorder', 7]]
#
# [['Psychosexual disorder', 5], ['Anemia', 5], ['Tendinitis', 4], ['Common cold', 1], ['Amyotrophic lateral sclerosis (ALS)', 9], ['Central retinal artery or vein occlusion', 8], ['Paroxysmal supraventricular tachycardia', 7], ['Venous insufficiency', 4], ['Trichomonas infection', 4], ['Acne', 4]]
#
# [['Depression', 7], ['Drug abuse', 7], ['Urinary tract obstruction', 7], ['Diabetes insipidus', 4], ['Iridocyclitis', 4], ['Varicocele of the testicles', 3], ['Irritable bowel syndrome', 3], ['Fracture of the foot', 5], ['Ovarian cyst', 3], ['Chlamydia', 4]]
#
# [['Parasitic disease', 3], ['Fracture of the jaw', 6], ['Cytomegalovirus infection', 7], ['Lipoma', 2], ['Female genitalia infection', 'Unknown'], ['Pulmonary hypertension', 7], ['Thyroid nodule', 3], ['Broken tooth', 3], ['Dumping syndrome', 'Unknown'], ['Lymphadenitis', 4]]
#
# [['Injury to the face', 7], ['Aortic valve disease', 5], ['Rheumatoid arthritis', 6], ['Spermatocele', 'Unknown'], ['Impetigo', 2], ['Anal fistula', 'Unknown'], ['Hypothermia', 8], ['Oppositional disorder', 5], ['Migraine', 7], ['Diabetic peripheral neuropathy', 4]]
#
# [['Testicular disorder', 7], ['Gestational diabetes', 'Unknown'], ['Hidradenitis suppurativa', 7], ['Valley fever', 3], ['Conjunctivitis due to bacteria', 4], ['Lewy body dementia', 7], ['Marfan syndrome', 7], ['Multiple myeloma', 7], ['Head injury', 7], ['Ascending cholangitis', 7]]
#
# [['Idiopathic irregular menstrual cycle', 1], ['Interstitial lung disease', 7], ['Mononeuritis', 3], ['Malaria', 7], ['Somatization disorder', 7], ['Hypovolemia', 7], ['Schizophrenia', 8], ['Knee ligament or meniscus tear', 4], ['Endocarditis', 7], ['Sepsis', 9]]
#
# [['Heat stroke', 8], ['Cholecystitis', 7], ['Cardiac arrest', 10], ['Cardiomyopathy', 7], ['Social phobia', 'Unknown'], ['Meningitis', 8], ['Spherocytosis', 6], ['Hormone disorder', 6], ['Raynaud disease', 'Unknown'], ['Reactive arthritis', 4]]
#
# [['Scabies', 4], ['Ear wax impaction', 2], ['Hypertension of pregnancy', 8], ['Peripheral arterial embolism', 7], ['Rosacea', 4], ['Fracture of the skull', 'Unknown'], ['Uveitis', 4], ['Fracture of the facial bones', 5], ['Tracheitis', 'Unknown'], ['Jaw disorder', 2]]
#
# [['Perirectal infection', 7], ['Breast cyst', 2], ['Post-traumatic stress disorder (PTSD)', 6], ['Kidney cancer', 6], ['Vulvar cancer', 8], ['Blepharitis', 2], ['Celiac disease', 5], ['Cystitis', 3], ['Sickle cell anemia', 7], ['Subconjunctival hemorrhage', 1]]
#
# [['Hemorrhoids', 4], ['Contact dermatitis', 3], ['Sinus bradycardia', 3], ['High blood pressure', 7], ['Pelvic inflammatory disease', 'Unknown'], ['Liver disease', 8], ['Chronic constipation', 4], ['Thyroid cancer', 6], ['Flu', 2], ['Friedrich ataxia', 6]]
#
# [['Tic (movement) disorder', 4], ['Skin polyp', 'Unknown'], ['Brachial neuritis', 4], ['Cervical cancer', 7], ['Adrenal adenoma', 1], ['Esophagitis', 5], ['Gas gangrene', 8], ['Yeast infection', 'Unknown'], ['Spina bifida', 7], ['Drug poisoning due to medication', 'Unknown']]
#
# [['Alcoholic liver disease', 9], ['Malignant hypertension', 9], ['Diverticulitis', 6], ['Moyamoya disease', 8], ['Heat exhaustion', 2], ['Psychotic disorder', 8], ['Frostbite', 8], ['Atrophy of the corpus cavernosum', 7], ['Smoking or tobacco addiction', 'Unknown'], ['Sprain or strain', 6]]
#
# [['Essential tremor', 'Unknown'], ['Open wound of the ear', 4], ['Foreign body in the nose', 4], ['Idiopathic painful menstruation', 'Unknown'], ['Down syndrome', 8], ['Idiopathic infrequent menstruation', 2], ['Pneumothorax', 7], ['De Quervain disease', 2], ['Fracture of the vertebra', 6], ['Human immunodeficiency virus infection (HIV)', 8]]
#
# [['Mumps', 3], ['Subarachnoid hemorrhage', 8], ['Acute fatty liver of pregnancy (AFLP)', 9], ['Ectropion', 4], ['Scar', 3], ['Lactose intolerance', 2], ['Eustachian tube dysfunction (ear disorder)', 3], ['Appendicitis', 6], ['Graves disease', 7], ['Dissociative disorder', 4]]
#
# [['Open wound of the face', 5], ['Dislocation of the vertebra', 7], ['Phimosis', 'Unknown'], ['Hyperemesis gravidarum', 7], ['Pregnancy', 5], ['Thalassemia', 8], ['Placenta previa', 7], ['Epidural hemorrhage', 9], ['Septic arthritis', 9], ["Athlete's foot", 3]]
#
# [['Pleural effusion', 3], ['Aphakia', 4], ['Vulvar disorder', 3], ['Vitamin B deficiency', 4], ['Sialoadenitis', 4], ['Gynecomastia', 2], ['Urinary tract infection', 3], ['Histoplasmosis', 5], ['Erythema multiforme', 6], ['Scoliosis', 4]]
#
# [['Bunion', 3], ['Arrhythmia', 7], ['Paget disease', 4], ['Trigeminal neuralgia', 9], ['Ankylosing spondylitis', 6], ['Peripheral nerve disorder', 5], ['Sebaceous cyst', 2], ['Poisoning due to antipsychotics', 'Unknown'], ['Behcet disease', 7], ['Neurosis', 6]]
#
# [['Prostate cancer', 7], ['Cerebral edema', 7], ['Dislocation of the finger', 3], ['Birth trauma', 7], ['Chronic pancreatitis', 7], ['Hematoma', 3], ['Carcinoid syndrome', 6], ['Open wound of the head', 7], ['Seborrheic keratosis', 1], ['Burn', 8]]
#
# [['Spontaneous abortion', 7], ['Genital herpes', 'Unknown'], ['Adjustment reaction', 3], ['Gallstone', 4], ['Multiple sclerosis', 7], ['Zenker diverticulum', 6], ['Fracture of the pelvis', 7], ['Pneumoconiosis', 6], ['Hyperlipidemia', 4], ['Ulcerative colitis', 6]]
#
# [['Male genitalia infection', 'Unknown'], ['HPV', 6], ['Angina', 5], ['Injury to the spinal cord', 7], ['Nasal polyp', 3], ['Lichen simplex', 5], ['Trichiasis', 4], ['Acariasis', 2], ['Colorectal cancer', 8], ['Skin pigmentation disorder', 3]]
#
# [['Factitious disorder', 8], ['Lymphogranuloma venereum', 7], ['Galactorrhea of unknown cause', 5], ['G6PD enzyme deficiency', 2], ['Nerve impingement near the shoulder', 5], ['Toxoplasmosis', 3], ['Fibroadenoma', 'Unknown'], ['Open wound of the hand', 'Unknown'], ['Missed abortion', 7], ['Diabetic ketoacidosis', 9]]
#
# [['Granuloma inguinale', 7], ['Hemorrhagic fever', 7], ['Obsessive compulsive disorder (OCD)', 5], ['Injury of the ankle', 3], ['Hyponatremia', 7], ['Stricture of the esophagus', 7], ['Fracture of the ankle', 'Unknown'], ['Soft tissue sarcoma', 8], ['Bone disorder', 5], ['Epilepsy', 'Unknown']]
#
# [['Personality disorder', 7], ['Shingles (herpes zoster)', 6], ['Tourette syndrome', 3], ['Avascular necrosis', 8], ['Strep throat', 5], ['Spinocerebellar ataxia', 7], ['Osteomyelitis', 6], ['Sjogren syndrome', 3], ['Adhesive capsulitis of the shoulder', 4], ['Viral hepatitis', 7]]
#
# [['Tonsillar hypertrophy', 6], ['Gastritis', 5], ['Skin cancer', 4], ['Rheumatic fever', 7], ['Aphthous ulcer', 3], ['Tonsillitis', 5], ['Intestinal cancer', 9], ['Rocky Mountain spotted fever', 7], ['Stomach cancer', 9], ['Developmental disability', 5]]
#
# [['Acute stress reaction', 3], ['Delirium', 7], ['Callus', 2], ['Guillain Barre syndrome', 7], ['Lumbago', 4], ['Deviated nasal septum', 3], ['Hemangioma', 4], ['Patau syndrome', 9], ['Peripheral arterial disease', 6], ['Chronic back pain', 7]]
#
# [['Heart failure', 8], ['Conjunctivitis', 3], ['Herniated disk', 6], ['Rhabdomyolysis', 7], ['Breast infection (mastitis)', 5], ['Abdominal aortic aneurysm', 7], ['Pulmonary embolism', 7], ['Conduct disorder', 8], ['Air embolism', 9], ['Mastectomy', 8]]
#
# [['Epididymitis', 4], ['Premature rupture of amniotic membrane', 'Unknown'], ['Molluscum contagiosum', 3], ['Necrotizing fasciitis', 9], ['Benign vaginal discharge (leukorrhea)', 'Unknown'], ['Bladder obstruction', 7], ['Melanoma', 8], ['Cervical disorder', 3], ['Laryngitis', 3], ['Dyshidrosis', 3]]
#
# [['Poisoning due to opioids', 'Unknown'], ['Diaper rash', 2], ['Lichen planus', 3], ['Gastroduodenal ulcer', 6], ['Inguinal hernia', 'Unknown'], ['Eczema', 4], ['Asperger syndrome', 6], ['Mucositis', 5], ['Paronychia', 3], ['Open wound of the jaw', 7]]
#
# [['White blood cell disease', 4], ['Kaposi sarcoma', 8], ['Spondylolisthesis', 4], ['Pseudotumor cerebri', 5], ['Conjunctivitis due to virus', 3], ['Open wound of the nose', 3], ['Seasonal Viral Flu', 2]]
